# %%
from dotenv import load_dotenv
import os
from langchain_openrouter import ChatOpenRouter
from langgraph.prebuilt import create_react_agent
from langchain_core.prompts import ChatPromptTemplate
from langchain.agents import create_agent
from tools.customer_tools import *
from tools.account_tools import *
from tools.order_tools import *
from tools.payment_tools import *
from tools.shipment_tools import *
from tools.refund_tools import *
from tools.dashboard_tools import *

# %%
load_dotenv();

# %%
tools = [
    get_customer,
    get_all_customers,
    search_customer,
    create_customer,
    update_customer_phone,
    activate_customer_account,
    deactivate_customer_account,
    delete_customer,
    customer_complete_summary,

    get_account,
    get_customer_accounts,
    deposit_money,
    withdraw_money,

    get_order,
    get_customer_orders,
    investigate_order_details,
    mark_order_delivered,

    get_payment,
    investigate_payment,
    list_failed_payments,

    get_shipment,

    investigate_refund,
    list_pending_refunds,

    dashboard_summary,
]
agent_executor = create_react_agent(llm, tools)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13064\1154712555.py:33: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(llm, tools)

# %%
def ask_agent(query):
    response = agent_executor.invoke({"messages": [("user", query)]})
    return response["messages"][-1].content

# %%
ask_agent("Give the customer details for the Customer ID:1")
# Out:
# 'The customer details for Customer ID 1 are:\n- Customer Name: Customer 1\n- Email: customer1@gmail.com\n- Phone: 9876541001\n- Status: INACTIVE\n- Created At: 2025-08-14 14:37:43'
